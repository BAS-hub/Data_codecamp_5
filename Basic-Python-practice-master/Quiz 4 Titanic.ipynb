# %%
## Quiz
import numpy as np ## ข้อ 1
import pandas as pd
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.tail(10) ## ข้อ 3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.sample(10) ## ข้อ 4
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 665          666         0       2               Hickman, Mr. Lewis    male
# 139          140         0       1               Giglio, Mr. Victor    male
# 524          525         0       3                Kassem, Mr. Fared    male
# 60            61         0       3            Sirayanian, Mr. Orsen    male
# 396          397         0       3              Olsson, Miss. Elina  female
# 838          839         1       3                  Chip, Mr. Chang    male
# 238          239         0       2  Pengelly, Mr. Frederick William    male
# 125          126         1       3     Nicola-Yarred, Master. Elias    male
# 821          822         1       3                Lulic, Mr. Nikola    male
# 372          373         0       3       Beavan, Mr. William Thomas    male
#
#       Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 665  32.0      2      0  S.O.C. 14879  73.5000   NaN        S
# ...

# %%
df.head(10) ## ข้อ 5
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(df['Embarked'].unique()) ## ข้อ 6
df1=df.dropna(subset = ['Embarked']) ## ลบข้อมูลที่ว่างในหลัก Embarked
df1
# Out:
# ['S' 'C' 'Q' nan]
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
avg = df['Age'].mean() ## ข้อ 7
df2 =df['Age'].fillna(value = avg)
df2
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df3 = df['Age'].fillna(value = 0 ) ## ข้อ 8
df3
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df4 = df.dropna(subset = ['Age']) ## ลบข้อมูลที่ว่างในหลัก Embarked
df4  ## ข้อ 9
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df['Sex'].value_counts()) ## ข้อ 10
print('Number Female / male =',314/577)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# Number Female / male = 0.5441941074523396

# %%
 df5 = df[['Sex','Survived']] 
df5
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
df5_2=df5[df5['Survived'] == 1] ## ข้อ 11
print(df5_2['Sex'].value_counts())
print("%Survived female = ",233*100/314," \n%Survived male = ",109*100/577)
df5_2
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64
# %Survived female =  74.20382165605096
# %Survived male =  18.890814558058924
#         Sex  Survived
# 1    female         1
# 2    female         1
# 3    female         1
# 8    female         1
# 9    female         1
# ..      ...       ...
# 875  female         1
# 879  female         1
# 880  female         1
# 887  female         1
# 889    male         1
#
# [342 rows x 2 columns]

# %%
df6=df.replace({'Sex' :{'male':1,'female':0}}) ## ข้อ 12
df6
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df7=df[df['Age'] >1] ## ข้อ 13
print("The youngest : Allison, Miss. Helen Loraine , 2 years old, Southampton\nThe oldest : Barkworth, Mr. Algernon Henry Wilson, 80 years old, Southampton")
df7.sort_values('Age')
# Out:
# The youngest : Allison, Miss. Helen Loraine , 2 years old, Southampton
# The oldest : Barkworth, Mr. Algernon Henry Wilson, 80 years old, Southampton
#      PassengerId  Survived  Pclass                                  Name  \
# 297          298         0       1          Allison, Miss. Helen Loraine
# 479          480         1       3              Hirvonen, Miss. Hildur E
# 16            17         0       3                  Rice, Master. Eugene
# 824          825         0       3          Panula, Master. Urho Abraham
# 205          206         0       3            Strom, Miss. Telma Matilda
# ..           ...       ...     ...                                   ...
# 116          117         0       3                  Connors, Mr. Patrick
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 851          852         0       3                   Svensson, Mr. Johan
# ...

# %%
df8=df[df['Fare'] >1] ## ข้อ 14
print("The lowest : Betros, Mr. Tannous, 20 years old, Dead\nThe highest : Ward, Miss. Anna, 35 years old, Survived")
df8.sort_values('Fare')
# Out:
# The lowest : Betros, Mr. Tannous, 20 years old, Dead
# The highest : Ward, Miss. Anna, 35 years old, Survived
#      PassengerId  Survived  Pclass                                Name  \
# 378          379         0       3                 Betros, Mr. Tannous
# 872          873         0       1            Carlsson, Mr. Frans Olof
# 326          327         0       3           Nysveen, Mr. Johan Hansen
# 843          844         0       3          Lemberopolous, Mr. Peter L
# 818          819         0       3    Holm, Mr. John Fredrik Alexander
# ..           ...       ...     ...                                 ...
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
#
# ...

# %%
df4['Pclass'].value_counts() ## ข้อ 15
avg = df4['Pclass'].mean()
avg
# Out:
# 2.2366946778711485

# %%
df9=df[df['Age'] > 50] ## ข้อ 16
df9['Survived'].value_counts()
# Out:
# 0    42
# 1    22
# Name: Survived, dtype: int64

# %%
check = df4.groupby(['Pclass']) ## ## ข้อ 17
check.describe()
# Out:
#        PassengerId                                                             \
#              count        mean         std   min    25%    50%     75%    max
# Pclass
# 1            186.0  463.962366  246.460706   2.0  271.0  486.0  669.75  890.0
# 2            173.0  447.156069  253.387868  10.0  233.0  433.0  671.00  887.0
# 3            355.0  441.219718  268.541525   1.0  195.5  425.0  683.50  891.0
#
#        Survived            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# Pclass                     ...
# 1         186.0  0.655914  ...   1.0  4.0  186.0  87.961582  80.857189   0.0
# 2         173.0  0.479769  ...   1.0  3.0  173.0  21.471556  13.187429  10.5
# 3         355.0  0.239437  ...   1.0  6.0  355.0  13.229435  10.043158   0.0
#
#
#              25%      50%       75%       max
# Pclass
# 1       34.17915  69.3000  106.4250  512.3292
# ...

# %%
df10 = df4[['Pclass','Fare']] ## ข้อ 18
print(df10[df10['Pclass'] == 1].max())
print(df10[df10['Pclass'] == 2].max())
print(df10[df10['Pclass'] == 3].max())
# Out:
# Pclass      1.0000
# Fare      512.3292
# dtype: float64
# Pclass     2.0
# Fare      73.5
# dtype: float64
# Pclass     3.0000
# Fare      56.4958
# dtype: float64

# %%
df11 = df4[['Age','Survived']] ## ข้อ 19
df11=df11[df11['Age'] > 1]
df12 =df11[df11['Age'] <= 10]
print(df12['Survived'].value_counts())
print("%Survived between 1 -10 years old = ",26*100/50)
df12 =df11[df11['Age'] > 10]
df12 =df12[df12['Age'] <= 20]
print(df12['Survived'].value_counts())
print("%Survived between 10 -20 years old = ",44*100/115)
df12 =df11[df11['Age'] > 20]
df12 =df12[df12['Age'] <= 30]
print(df12['Survived'].value_counts())
print("%Survived between 20 -30 years old = ",100*84/230)
df12 =df11[df11['Age'] > 30]
df12 =df12[df12['Age'] <= 40]
print(df12['Survived'].value_counts())
print("%Survived between 30 -40 years old = ",100*69/155)
df12 =df11[df11['Age'] > 40]
df12 =df12[df12['Age'] <= 50]
print(df12['Survived'].value_counts())
print("%Survived between 40 -50 years old = ",100*33/86)
df12 =df11[df11['Age'] > 50]
df12 =df12[df12['Age'] <= 60]
print(df12['Survived'].value_counts())
print("%Survived between 50 -60 years old = ",100*17/42)
df12 =df11[df11['Age'] > 60]
df12 =df12[df12['Age'] <= 70]
print(df12['Survived'].value_counts())
print("%Survived between 60 -70 years old = ",100*4/17)
df12 =df11[df11['Age'] > 70]
df12 =df12[df12['Age'] <= 80]
print(df12['Survived'].value_counts())
print("%Survived between 70 -80 years old = ",100*1/5)
# Out:
# 1    26
# 0    24
# Name: Survived, dtype: int64
# %Survived between 1 -10 years old =  52.0
# 0    71
# 1    44
# Name: Survived, dtype: int64
# %Survived between 10 -20 years old =  38.26086956521739
# 0    146
# 1     84
# Name: Survived, dtype: int64
# %Survived between 20 -30 years old =  36.52173913043478
# 0    86
# 1    69
# Name: Survived, dtype: int64
# %Survived between 30 -40 years old =  44.516129032258064
# 0    53
# 1    33
# Name: Survived, dtype: int64
# %Survived between 40 -50 years old =  38.372093023255815
# 0    25
# 1    17
# Name: Survived, dtype: int64
# %Survived between 50 -60 years old =  40.476190476190474
# 0    13
# 1     4
# Name: Survived, dtype: int64
# %Survived between 60 -70 years old =  23.529411764705884
# 0    4
# 1    1
# Name: Survived, dtype: int64
# %Survived between 70 -80 years old =  20.0

# %%
df4.sort_values('Fare') ## ข้อ 20
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 179          180         0       3                 Leonard, Mr. Lionel
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 597          598         0       3                 Johnson, Mr. Alfred
# 263          264         0       1               Harrison, Mr. William
# ..           ...       ...     ...                                 ...
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 438          439         0       1                   Fortune, Mr. Mark
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df4.sort_values('Fare')[::-1]  ## ข้อ 21
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# ..           ...       ...     ...                                 ...
# 263          264         0       1               Harrison, Mr. William
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 179          180         0       3                 Leonard, Mr. Lionel
# 271          272         1       3        Tornquist, Mr. William Henry
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df13=df4['Name']  
y = [ i.split(',').pop(0) for i in df13 ]
df['New Name'] = pd.Series(y)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df14 = df['New Name']  ## ข้อ 23
df14=df14.dropna(axis=0)
df15=df14.drop_duplicates()
print(len(df15))
df15
# Out:
# 535
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 707     Banfield
# 708     Sutehall
# 710     Montvila
# 712         Behr
# 713       Dooley
# Name: New Name, Length: 535, dtype: object

# %%
df14=df14[df14.duplicated()] ##ข้อ 22
df14=df14.dropna(axis=0)
df14.value_counts()
# Out:
# Andersson     6
# Johnson       3
# Goodwin       3
# Skoog         3
# Panula        3
# Carter        3
# Rice          2
# Brown         1
# Baclini       1
# Asplund       1
# Palsson       1
# Fortune       1
# Ford          1
# Gustafsson    1
# Harris        1
# Harper        1
# Name: New Name, dtype: int64
